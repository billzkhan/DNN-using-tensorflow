# %% [markdown]
# # Colaboratory 열어주세요!

# %%
import pandas as pd

# %%
pd.Series(['SF', 'SJ', 'Sacra'])
# Out:
# 0       SF
# 1       SJ
# 2    Sacra
# dtype: object

# %%
city_names = pd.Series(['San Francisco', 'San Jose', 'Sacramento'])
population = pd.Series([852469, 1015785, 485199])

pd.DataFrame({'City name': city_names, 'Population':population})
# Out:
#        City name  Population
# 0  San Francisco      852469
# 1       San Jose     1015785
# 2     Sacramento      485199

# %%
df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv", sep=",")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  17000.000000  17000.000000  ...   17000.000000        17000.000000
# mean    -119.562108     35.625225  ...       3.883578       207300.912353
# std        2.005166      2.137340  ...       1.908157       115983.764387
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.790000     33.930000  ...       2.566375       119400.000000
# 50%     -118.490000     34.250000  ...       3.544600       180400.000000
# 75%     -118.000000     37.720000  ...       4.767000       265000.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %%
df.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]

# %%
df.hist("housing_median_age")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6d596723c8>]],
#       dtype=object)

# %%
type(df['longitude'])
# Out:
# pandas.core.series.Series

# %%
df['longitude'][0:2]
# Out:
# 0   -114.31
# 1   -114.47
# Name: longitude, dtype: float64

# %%
cities = pd.DataFrame({'City name': city_names, 'Population':population})

cities['area'] = pd.Series([46,166,97])

cities
# Out:
#        City name  Population  area
# 0  San Francisco      852469    46
# 1       San Jose     1015785   166
# 2     Sacramento      485199    97

# %%
cities.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
cities = cities.reindex([2,0,1])

# %%
cities
# Out:
#        City name  Population  area
# 2     Sacramento      485199    97
# 0  San Francisco      852469    46
# 1       San Jose     1015785   166

# %%
cities.iloc[[0,2]]
# Out:
#     City name  Population  area
# 2  Sacramento      485199    97
# 1    San Jose     1015785   166
